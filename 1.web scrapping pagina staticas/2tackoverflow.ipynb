# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36",
}

url='https://stackoverflow.com/questions'

response=requests.get(url,headers)
soup=BeautifulSoup(response.text)

questions=soup.find(id='questions')
questions_list = questions.find_all('div', id=lambda x: x and x.startswith('question-summary'))

for question in questions_list:
    element = question.find('h3')
    title=element.get_text()

    description=element.find_next_sibling('div').text.replace('\n','').replace('\r','').strip()
    print(title)
    print(description)
# Out:
# @salesforce directory missing in 'c:\\Users\\myUserName\\.vscode\\extensions\\salesforce.salesforcedx-vscode-core-62.9.1\\node_modules\\
#
# PROBLEM:The following is listed as a Problem in a VSCode Salesforce project.[{    "resource": "/c:/Users/myUserName/Desktop/salesforce_junk/debugger-project/sfdx-project.json", ...
#
# How to locally test javascript that contains classes that require secure context
#
# On Mac, I am trying to test some website javascript that involves AudioWorkletProcessor.Apparently this class is "only available in a secure context."I'm assuming this means that the ...
#
# Encryption library in PineScript?
#
# Is there a reliable PineScript encryption library or function (native or community-contributed library) that uses a Key to hash a text/string? Whether it is AES, or any of the standard ones.
#
# Can Compose Multiplatform navigate and change routes on Web while maintaining URL state?
#
# I've been exploring Compose Multiplatform and went through the documentation, particularly Compose Multiplatform Navigation Routing. Despite the library being supported on the web, the docs mention ...
#
# Pytesseract numbers image to text
#
# I am trying to use pytesseract to extract numbers from images.It works for some of them (1, 2, 3, 5, 6, 20...) but I would like to make it work for all of them.Here is a sample of the data that i'm ...
#
# Unable to receive customer initiated messages in webhook - Whatsapp Cloud API Webhook
#
# Unable to receive customer initiated messages in webhook - WhatsApp Cloud API Webhook. I had subscribed to all events and when trying test from developers console of meta, webhook is called with POST. ...
#
# Next.js 15 Page Flipping Animation Issues
#
# ContextI'm trying to port a React.js page flipping animation tutorial to Next.js 15 with TypeScript and Tailwind CSS. The project involves a 3D book model with animated page flips.Current Issues...
#
# Editable DataGridViewComboBox column bound to data source, or how to handle CellValidating event in custom column
#
# I have a combo box column in DataGridView bound to data source to select item from subtable, and I want the combobox to be editable (combobox with ComboBoxStyle.DropDown style). My first idea was to ...
#
# Is there a Block Based IDE for ESP32 that is still maintained in 2024? [closed]
#
# I am trying to work on Block-Based Robot programming with my daughter using ESP32-WROOM-32D. I can get everything working with Platform.io but she is used to using Block Programming. I took a look at ...
#
# Can LlamaParse return as a pydantic object?
#
# I have been unable to make LlamaParse return the parsed content in a strictly structured format,like Pydantic objects. Otherwise I would have to make a separate api call just to make it the parsed ...
#
# Why system can't run dynamic SQL with bind variable C#?
#
# I have the function query data from DB. In the past, we used System.Client.Oracle and the code below worked:{    text2 += "     LEFT JOIN CONTACT_GROUP CG ON C.CONTACT_ID = CG.CONTACT_ID \r\n ...
#
# Javascript in NextJS - How To Structure?
#
# Hoping someone can help! I'm building a nextJS website and wanting to incorporate some javascript. I want this javascript to run each time a user navigates to a separate page.Let's say I want to log ...
#
# Why does z-index work in input::-webkit-slider-thumb but not input::-moz-range-thumb?
#
# The code snippet below inserts the pink div between the range slider's track and thumb.Why does it work in other browsers (-webkit-slider-thumb), but not Firefox (-moz-range-thumb)?The element ...
#
# coturn, coturn-credential-api + peerjs Failed to construct 'RTCPeerConnection': Both username and credential are required
#
# I have a webpage that uses peerjs to create a WebRTC connection. It works fine when using their cloud server.I then use coturn as the iceServer. This works fine when setting static user credentials ...
#
# Debugging in R Studio
#
# Have read alot about debugging in R Studio, but still have a few basic questions:Where do you place the debug() statements? Before the function definitions? Before library() statements?Does ...
#
# Determining Which Points on the Perimeter of a Circle Fall Between Two Other Points That Are on Its Radius
#
# I have a circle with a known radius centered at the origin.Radius <- 1Horizontal_Coordinates <- seq(-Radius, Radius, 0.01)Positive_Vertical_Coordinates <- sqrt((Radius ^ 2) - (...
#
# App not opening in react-native on click of notification
#
# I am using React Native Notifee for displaying notifications and encountering an issue where the app does not open upon clicking a notification.This problem occurs in two specific scenarios:When the ...
#
# Polars Rust Napi borrower checker
#
# When creating a Polars Rust Napi function, I am running into a borrower checker error:returns a value referencing data owned by the current functionAny help would be appreciated. Thx#[napi(...
#
# Livewire 3 Browser History
#
# I'm new to Livewire. I learned that Livewire default is to replace state but it seems pushing state. I created the following simple pages, but when I navigate to the second page, I can still see the ...
#
# If I am using Spring Security and Spring AI how do I make it so MessageChatMemoryAdvisor is per session?
#
# I currently have a simple working prototype with Spring AI. Currently this is setup like    @Bean    public ChatClient buildClient(            MessageChatMemoryAdvisor messageChatMemoryAdvisor    )...
#
# htmx: Selecting multiple classes in hx-trigger
#
# I have the following code (simplified):<div hx-post="/handle" hx-trigger="click from:.test1,.test2" hx-swap="outerHTML">    <div class="checkboxes"&...
#
# multi-module gradle build files to instrument a (application) submodule with a (agent) submodule
#
# I have a multiple-module gradle project where one module A needs to be instrumented by a java-agent whose source-code is in module B.How do I structure my gradle project to achieve that goal ?If ...
#
# Restore state of previous composable when navigating back
#
# I'm having some issues with state and navigation in Compose.I have a screen A with a searchbar. When a result of the search is clicked it navigates to a detail screen and when I navigate back, screen ...
#
# PIC18F25K80 Sleep Mode
#
# I've been working on a project with PIC18F25K80 MCU for a while. My main purpose is to collect some sensor data based on user-defined intervals(like 1min) and since this is a battery-powered ...
#
# Why can't I access my environment secret?
#
# I have configured a dev environment with a Firebase secret, but I can't write it to my .env.local file when running the CI. Only repository-level secrets work.How can I access my environment secret?...
#
# How to setup the DISPLAY in a Ubuntu Linux docker container? Everything is inside Windows OS [closed]
#
# I am in Windows 11 PC environment.I am using the Docker Container.    docker pull ubuntu    docker run -ti --rm ubuntu bashNow I am inside the Ubuntu Linux env. The problem here I cann't setup the ...
#
# How to add Distortion Coefficients to Unity Camera?
#
# I am currently working on a Unity Project with HDRP to export Images for the training of a Machine Learning Model. Therefore Unity needs to ouput images with the same distortion as my physical camera ...
#
# NextJS Zustand (server fetching)
#
# This might be a question that's asked several times but being new to both NextJS and Zustand, I am having trouble understanding some concepts.This is my zustand store:import { Category } from "@...
#
# Launch Automator Workflow and pass parameter from Apple Script
#
# I have:an Automator workflow saved as an application "workflow.app"an Apple Script saved as an application "script.app"a PDF file residing on Desktop "test.pdf"How ...
#
# What is the effect of sizeof for hypothetically oversized objects?
#
# Suppose we have the source:#include <stddef.h>struct foo{    char b ;    char a [ SIZE_MAX ] ;} ;int main ( void ){    const size_t z = sizeof ( struct foo ) ;    printf("%zu\n&...
#
# using Twilio step on Zapier for dyanmic set of receives/messages
#
# I have a code-by-Zapier step that returns this:console.log({inputData});return {"messages":[  {"to":"+17375554824","val":"hi there alex"},  {&...
#
# NativeBase Progress Component Error: Loss of Precision During Arithmetic Conversion
#
# I am using React Native with NativeBase, and I encountered the following error while rendering the Progress component:(NOBRIDGE) ERROR  Warning: Error: Exception in HostFunction: Loss of precision ...
#
# How to change line spacing in a multiline JButton
#
# Since multiline buttons can be created with html text, I tried html's line-height attribute with decimal, pixel and percentage values to change the vertical line spacing. But in vain.import java.awt.*...
#
# translate .net 6 to .net 4.8 c# ImportRSAPrivateKey not exists
#
# I am trying to translate this C# .net 6.0 code to C# .net 4.8. I am trying to get a token using a RSA private key pem file. But I didn't succeed.Please, someone can help me ?I have a problem with ...
#
# Bonjour scan keeps failing on iOS 18
#
# I am using this Xcode project that should display bonjour devices, it's a little bit old so I realise I have to add permissions in the plist to make it work.https://github.com/mrmitew/Bonjour-iOSI ...
#
# Wolfram Mathematica - Why I can't ReleaseHold y'[x]?
#
# For some reason, y'[x] is equal to 22/13, and I cannot delete it in any way I know or I have investigated.I tried Clearing All with ClearAll["Global`*"] and ReleaseHold[Derivative[1][y][x]],...
#
# Laravel Blade: x-base-component not rendering correct HTML tag
#
# I am trying to create a dynamic Laravel Blade component that can render different HTML tags using a tag property. I am using a base-component and a button component. However, when I render the button ...
#
# funny behavior with a scrolling table
#
# In my experience I have found that there is no one size fits all when it comes to CSS scrolling tables. Every time I implement them I have to create a new way to do it because the previous ways didn't ...
#
# "Error during migration run" when starting NestJS server that was bootstrapped with brocoder's boilerplate code in docker container
#
# I cloned brocoder's NestJS server boilerplate code, found here: https://github.com/brocoders/nestjs-boilerplate/tree/mainI followed these instructions to install/start the server: https://github.com/...
#
# Django Rest Framework: validate_username and update methods not called during PUT request
#
# I am working on a Django Rest Framework (DRF) project, where I need to validate a username field and handle custom update logic in a serializer. My model has a username field with unique=True. Here's ...
#
# How to download YouTube videos using pydub?
#
# Changes in Youtube in 2024 caused you-get and pydub to not operate smoothly.How to download YouTube videos using pydub?(I just want to share a solution.)
#
# Getting the Updated Width & Height of a ViewGroup
#
# I have a .NET for Android app containing a GridLayout for which I need the Width/Height. Right now both of these return 0, which is not surprising, since I am attempting to access them in OnResume. ...
#
# Accessing header in handshakeinterceptor springboot websocket and react
#
# I am making realtime chat application using websocket with springboot ,sockJS and stomp.I want to display the "User left" or "User Joined" message in chat. For this I am sending ...
#
# Tailwind 'dark:' not working with Next 15, next-themes, and Tailwind 4
#
# I've got the light mode switch working, but now Tailwind's 'dark:' class modifier does not work.Following these instructions: Implementing Dark Mode and Theme Switching using Tailwind v4 and Next.js...
#
# How quotes in bash loop's command affect control flow?
#
# Seeing something that is making me question my sanity:#!/bin/env bashset -efor d in '/tmp/somedir/*'; do                   for f in "${d}/*pub"; do        echo $f;    donedoneit ...
#
# Why doesn't rotate() work when I translate my object? [duplicate]
#
# I have an image in my webpage that I want to rotate, but it goes out of it's position and glitches out when I use both transform translate() and transform rotate(). I tried repositioning the lines of ...
#
# Is it possible to sync data in background React Native?
#
# I'm struggling with a functionality in my app since few weeks.I will explain my project ; I have a react native app, that connect multiples user. A user can create an event, like a meeting, and the ...
#
# How to pull up Django model data based on ALREADY filled out form fields for other ForeignKeys
#
# I have a form in which there are several fields with foreign keys. For example, the table "Entrance" (3 entries -> 1st entrance, 2nd entrance, 3rd entrance), "Apartment" (30 ...
#
# How can a node.js application start automatically when launching an Ubuntu system on WSL?
#
# I have in my Ubuntu 24.04.01 LTS system (under WSL) a node.js application (which was installed through npm) and runs with the command "mynode run".How can I automate this to run when I ...
